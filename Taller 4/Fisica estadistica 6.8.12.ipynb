# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def entropia(x):
    entropiaSobreKbN = -1*(x*np.log(x) + (1-x)*np.log(1-x))
    return entropiaSobreKbN

# %%
x = np.linspace(0.01,0.99,10000)
y = entropia(x)

# %%
plt.plot(x,y)
